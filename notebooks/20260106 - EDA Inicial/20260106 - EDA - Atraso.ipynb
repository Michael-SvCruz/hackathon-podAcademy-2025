# %%
atraso = spark.read.parquet("/Volumes/workspace/hackathon_2025/default/source/book_atraso/dados_faturamento/")

# %%
display(atraso)

# %%
atraso.registerTempTable("atraso")

# %%
# %sql
SELECT * from atraso
WHERE NUM_CPF = "79X9TWTZ8TW"
