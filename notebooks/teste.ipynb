# %% [markdown]
# ## Notebook de teste
# Um notebook simples de teste, para os membros da equipe se certificarem que os caminhos e arquivos foram criados e alocados nos locais correspondente

# %%
# caminho da fonte
source = '/Volumes/hackathon_2025/default/source'

# %%
# Listar dados da fonte 
display(dbutils.fs.ls(source))

# %%
# visualizando base_dados_cadastrais

df_cadastro = spark.read.format('parquet') \
    .load('dbfs:/Volumes/hackathon_2025/default/source/base_dados_cadastrais/')
display(df_cadastro)

# %%
# visualizando base_score_bureau_movel

df_bureau = spark.read.format('parquet') \
    .load('dbfs:/Volumes/hackathon_2025/default/source/base_score_bureau_movel/')

display(df_bureau)

# %%
# visualizando base_telco

df_telco = spark.read.format('parquet') \
    .load('dbfs:/Volumes/hackathon_2025/default/source/base_telco/')

display(df_telco)

# %%
# visualizando base recarga

df_recarga = spark.read.format('parquet') \
    .load('dbfs:/Volumes/hackathon_2025/default/source/bases_recarga/BI_FP_ASS_RECARGA_CMV_NOVA/')

display(df_recarga)

# %%
# visualizando book_atraso

df_atraso = spark.read.format('parquet') \
    .load('dbfs:/Volumes/hackathon_2025/default/source/book_atraso/dados_faturamento/')

display(df_atraso)

# %%
# visualizando book_pagamento

df_pagamento = spark.read.format('parquet') \
    .load('dbfs:/Volumes/hackathon_2025/default/source/book_pagamento/dados_pagamento/')

display(df_pagamento)
