# %%
path = "/Volumes/hackathon_2025/default/bronze/bureau_full_delta/"

# %%
df = spark.read.format("delta").load(path)

display(df)

# %%
path_silver = "/Volumes/hackathon_2025/default/silver/bureau_full_delta/"

# %%
df_silver = spark.read.format("delta").load(path_silver)

display(df_silver)

# %%
path_2 = "/Volumes/hackathon_2025/default/silver/bureau_full_silver_delta/"
df_silver = spark.read.format("delta").load(path_2)

display(df_silver)

# %%
# %sql
CREATE TABLE IF NOT EXISTS hackathon_2025.default.00_bronze_bureau
USING DELTA
LOCATION '/Volumes/hackathon_2025/default/bronze/bureau_full_delta/';

# %%
target_table = "hackathon_2025.default.bronze_bureau"
df_silver.write.mode("overwrite").saveAsTable(target_table)

# %%
# %sql
SELECT * FROM hackathon_2025.default.bronze_bureau

# %%
# %sql
SELECT * 
FROM hackathon_2025.default.silver_bureau
LIMIT 10

# %%
# %sql
SELECT
  COUNT(*) AS total,
  COUNT(DISTINCT CONCAT(NUM_CPF,'#',SAFRA)) AS distinct_key,
  COUNT(*) - COUNT(DISTINCT CONCAT(NUM_CPF,'#',SAFRA)) AS duplicadas
FROM hackathon_2025.default.silver_bureau;

# %%
# %sql
SELECT FLAG_INSTALACAO_INT
, COUNT(*) AS qtd
FROM hackathon_2025.default.silver_bureau
GROUP BY 1
ORDER BY qtd DESC;

# %%
# %sql
SELECT
  SUM(CASE WHEN FLAG_SCORE01_MISSING = 1 THEN 1 ELSE 0 END) AS score01_missing,
  COUNT(*) AS total
FROM hackathon_2025.default.silver_bureau;

# %%
# %sql
SELECT
  FLAG_INSTALACAO_INT AS flag_instalacao,
  FPD_INT AS fpd,
  COUNT(*) AS qtd
FROM hackathon_2025.default.silver_bureau
GROUP BY 1,2
ORDER BY 1,2;

# %%
# %sql
CREATE OR REPLACE TABLE hackathon_2025.default.gold_spine AS
  SELECT
    NUM_CPF,
    SAFRA,
    DT_SAFRA,
    FLAG_INSTALACAO_INT,
    FPD_INT,
    SCORE_01_ADJ,
    FLAG_SCORE01_MISSING
  FROM hackathon_2025.default.silver_bureau

# %%
# %sql
SELECT
  NUM_CPF,
  SAFRA,
  DT_SAFRA,
  FLAG_INSTALACAO_INT,
  FPD_INT,
  SCORE_01_ADJ,
  FLAG_SCORE01_MISSING
FROM hackathon_2025.default.silver_bureau;

# %%
# %sql
SELECT * FROM hackathon_2025.default.gold_spine
